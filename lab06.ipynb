# %%
def vowel():
 a = input("Enter a value:" ) #taking input from users
 print (a)
 count = 0 # a count variable with 0
 for v in a: #using for loop to find the total numbers of vowels
    if (v== "a" or v=="e"or v=="i" or v =="o" or v=="u" or v=="A" or v=="E" or v=="I" or v=="O" or v=="U") :
       count= count+1 #if this finds "aeiouAEIOU" in the string then it increments the value of the count by 1
 print ("the number of vowels in a",count) #print the number of vowels in the string
 x=0 #taking count variables with 0
 y=0
 z=0
 m=0
 n=0
 u=0
 k=0
 b=0
 q=0
 n=0

 for v in a: 
    if(v=="a"):  #finding only a in the string 
      x= x+1  #if this finds a in the string it increments the value of x by 1
 print ("the numbers of a's", x) #printing the number of a
 for v in a:
    if(v=="e"):
      y= y+1
 print ("the numbers of e's", y)
 for v in a:
    if(v=="i"):
      z= z+1
 print ("the numbers of i's", z)
 for v in a:
    if(v=="o"):
      m= m+1
 print ("the numbers of o's", m)
 for v in a:
    if(v=="u"):
      n= n+1
 print ("the numbers of u's", n)
 for v in a:
    if(v=="A"):
      u= u+1
 print ("the numbers of A's", u)
 for v in a:
    if(v=="E"):
      k= k+1
 print ("the numbers of E's", k)
 for v in a:
    if(v=="I"):
      b= b+1
 print ("the numbers of I's", b)
 for v in a:
    if(v=="O"):
      q= q+1
 print ("the numbers of O's", q)
 for v in a:
    if(v=="U"):
      n= n+1
 print ("the numbers of U's", n)
 length =len(a)
 percen=((count/len(a))*100)
 print(percen)
